# %%
""" NLP: natuaral language Processing
    NLP is a branch of AI and DL/ML that enables computer to understand,
    read, write, and generate human language.
    Relationship: AI ---> ML ---> DL ---> NLP
    Ex.1 preson( only understand hindi and english) ----> person(who can only understand japanese)
    google transalter help.
    => computer understood one language and convert it into another -> NLP
    Ex.2  Applocation of NLP:
          google assisstant
          chatgpt
          alexa
          translater
          chatbots
          search engine
    Why do we need NLP?
      -> computer understand only numbers.
      -> person communicate using -> Hindi, English,...etc.
      -> NLP converts human language into form computer can understand.
    NLP workflow:

    Types of NLP taskd:
      1. Text Classification:
        -> classify text into categories.
        ex. spam/not spam
      2. Sentiment Analysis:
        -> find customer opionian
        ex. poositive/negative/neutral
      3. Machine Translation:
        -> Translate one language into another.
        ex. hindi -> english/ english -> hindi
      4. Text Summarizing & moral
        -> converts long article into short summaries.
        ex. story --> moral
      5. Question Answering:
        ex. Chatgpt/google search
      6. Named Entity recognition:
        ex. Elon musk founded tesla
            entities -> Elon musk-> Person
                        Tesla -> organisation
      7. Search into Text
      8. Chatgpt-> article, email,code
    Common NLP Libraries/ Package:
      libraries/package  |   Purpose
           NLTK          |   Basic NLP
           Spacy         |   Fast NLP
           TextBlob      |   Sentiment analysis
           Gensim        |   Topic Modelling
           Transformer   |   Modern NLP models
      Text cleaning:
        -> before traing a model.
        -> we removed unwanted info.
        ex. hello!! welcome   AI026.
        removes:- Emojis, numbers, punctuation, html, tags,
                  extra spaces, special characters
"""
# Out:
# ' NLP: natuaral language Processing\n    NLP is a branch of AI and DL/ML that enables computer to understand,\n    read, write, and generate human language.\n    Relationship: AI ---> ML ---> DL ---> NLP\n    Ex.1 preson( only understand hindi and english) ----> person(who can only understand japanese)\n    google transalter help.\n    => computer understood one language and convert it into another -> NLP\n    Ex.2  Applocation of NLP:\n          google assisstant\n          chatgpt\n          alexa \n          translater\n          chatbots\n          search engine\n    Why do we need NLP? \n      -> computer understand only numbers.\n      -> person communicate using -> Hindi, English,...etc.\n      -> NLP converts human language into form computer can understand.\n    NLP workflow:\n\n    Types of NLP taskd:\n      1. Text Classification:\n        -> classify text into categories.\n        ex. spam/not spam\n      2. Sentiment Analysis:\n        -> find customer opionian\n        
# ...

# %%
# !pip install NLTK

# %%
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
text = "I love Machine Learning"
tokens = word_tokenize(text)
print(tokens)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ['I', 'love', 'Machine', 'Learning']

# %%
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
text = "My name is Harsh Gupta"
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['My', 'name', 'is', 'Harsh', 'Gupta']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')

text = " I am learning Machine Learning with Rajendra sir"
words = word_tokenize(text)
print("tokenize")
print(words)
stop_words = set(stopwords.words('english'))
print("stop words")
print(stop_words)
# filter data
# filtered_words = [word for word in words if word.lower() not in stop_words]
filtered = []
for word in words:
    if word.lower() not in stop_words:
        filtered.append(word)
print("filtered words")
print(filtered)
# Out:
# tokenize
# ['I', 'am', 'learning', 'Machine', 'Learning', 'with', 'Rajendra', 'sir']
# stop words
# ...

# %%
# stemming/lemmatization => converts words into their root form
from nltk.stem import PorterStemmer
Stemmer = PorterStemmer()
print(Stemmer.stem("playing"))
print(Stemmer.stem("player"))
print(Stemmer.stem("played"))
# Out:
# play
# player
# play

# %%
import nltk

nltk.download("punkt")
nltk.download("stopwords")

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

review = "This mobile phone has an amazing camera and excellent battery backup."

# Tokenization
tokens = word_tokenize(review)

# Stopword
stop_words = set(stopwords.words("english"))
filtered = [word for word in tokens if word.lower() not in stop_words]

# Stemming
stemmer = PorterStemmer()
stemmed = [stemmer.stem(word) for word in filtered]

print("Original Review:")
print(review)

print("\nTokens:")
print(tokens)

print("\nAfter Stopword Removal:")
print(filtered)

print("\nAfter Stemming:")
print(stemmed)
# Out:
# Original Review:
# This mobile phone has an amazing camera and excellent battery backup.
#
# Tokens:
# ['This', 'mobile', 'phone', 'has', 'an', 'amazing', 'camera', 'and', 'excellent', 'battery', 'backup', '.']
#
# After Stopword Removal:
# ['mobile', 'phone', 'amazing', 'camera', 'excellent', 'battery', 'backup', '.']
#
# After Stemming:
# ['mobil', 'phone', 'amaz', 'camera', 'excel', 'batteri', 'backup', '.']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import nltk

# Run these only once
nltk.download("punkt")
nltk.download("stopwords")

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# Large paragraph
text = """
I recently purchased this smartphone from an online store after reading many positive reviews.
The delivery was quick and the packaging was excellent. The display quality is amazing,
the camera captures beautiful photos, and the battery lasts all day without any issues.
However, the phone becomes slightly warm while playing heavy games, and the charging speed
could have been better. Overall, I am satisfied with this product because it offers great
performance, excellent features, and good value for money. I would definitely recommend
this smartphone to anyone looking for a reliable and affordable device.
"""


print("ORIGINAL PARAGRAPH")
print(text)

# Word Tokenization
tokens = word_tokenize(text)

print("WORD TOKENS")
print(tokens)

# Stop Word Removal
stop_words = set(stopwords.words("english"))

filtered_words = []

for word in tokens:
    if word.lower() not in stop_words:
        filtered_words.append(word)

print("AFTER STOP WORD REMOVAL")
print(filtered_words)

# Stemming
stemmer = PorterStemmer()

stemmed_words = []

for word in filtered_words:
    stemmed_words.append(stemmer.stem(word))

print("AFTER STEMMING")
print(stemmed_words)
# Out:
# ORIGINAL PARAGRAPH
#
# I recently purchased this smartphone from an online store after reading many positive reviews.
# The delivery was quick and the packaging was excellent. The display quality is amazing,
# the camera captures beautiful photos, and the battery lasts all day without any issues.
# However, the phone becomes slightly warm while playing heavy games, and the charging speed
# could have been better. Overall, I am satisfied with this product because it offers great
# performance, excellent features, and good value for money. I would definitely recommend
# this smartphone to anyone looking for a reliable and affordable device.
#
# WORD TOKENS
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
groups = ["A", "B", "C", "D"]

boys = [10, 20, 15, 25]
girls = [15, 25, 20, 30]
teachers = [5, 8, 6, 10]
x = np.arange(len(groups))
w = 0.25
plt.figure(figsize=(8,5))

plt.bar(
    [i - w for i in x],
    boys,
    width=w,
    label="Boys"
)

plt.bar(
    x,
    girls,
    width=w,
    label="Girls"
)

plt.bar(
    [i + w for i in x],
    teachers,
    width=w,
    label="Teachers"
)

plt.xticks(x, groups)

plt.xlabel("Groups")
plt.ylabel("Number of People")
plt.title("Group Comparison")

plt.legend()
plt.grid(axis="y")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
 
groups = ["A", "B", "C", "D"]
 
A = [10,20,15,25]
B = [15,25,20,30]
C = [5,8,6,10]
D = [12,18,14,22]
 
x = np.arange(len(groups))
w = 0.2
 
plt.bar(x-1.5*w, A, width=w, label="A")
plt.bar(x-0.5*w, B, width=w, label="B")
plt.bar(x+0.5*w, C, width=w, label="C")
plt.bar(x+1.5*w, D, width=w, label="D")
 
plt.xticks(x, groups)
 
plt.xlabel("Groups")
plt.ylabel("Values")
plt.title("4 Bar Comparison")
 
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

groups = ["A", "B", "C", "D","E"]

A = [10,20,15,25,28]
B = [15,25,20,30,24]
C = [5,8,6,10,12]
D = [12,18,14,22,15]
E = [4,3,15,25,30]

x = np.arange(len(groups))
w = 0.15

plt.bar(x-2*w, A, width=w, label="A")
plt.bar(x-w, B, width=w, label="B")
plt.bar(x, C, width=w, label="C")
plt.bar(x+w, D, width=w, label="D")
plt.bar(x+2*w, E, width=w, label="E")
plt.xticks(x, groups)

plt.xlabel("Groups")
plt.ylabel("Values")
plt.title("5 Bar Comparison")

plt.legend()
plt.show()

# %%
marks = [40,55,60,70,75,90,33,50]
plt.hist(marks, bins=5)
plt.show()

# %%
# pie chart
fruits =  ['apple','banana','orange','watermelon']
count = [40,30,15,70]
plt.pie(count, labels = fruits)
plt.show()

# %%
fruits =  ['apple','banana','orange','watermelon']
count = [40,30,15,70]
colors = ['red','yellow','orange','green']
explode = [0.1,0,0,0]
plt.pie(count,labels=fruits, colors=colors, startangle=90, autopct="%1.1f%%",shadow=True,explode=explode,wedgeprops={"edgecolor":"black"})
plt.show()

# %%
# First Chart
plt.subplot(1,2,1)

x = [1,2,3,4,5]
y = [10,20,30,40,55]

plt.plot(x,y)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Line Chart")

# Second Chart
plt.subplot(1,2,2)

x1 = ['apple','banana','orange','watermelon']
y1 = [40,30,15,70]

plt.pie(
    y1,
    labels=x1,
    autopct="%1.1f%%"
)

plt.title("Fruit Distribution")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10,8))

# 1. Line Chart
plt.subplot(2,2,1)

x = [1,2,3,4,5]
y = [10,20,30,40,50]

plt.plot(x,y,marker='o')
plt.title("Line Chart")
plt.xlabel("X")
plt.ylabel("Y")

# 2. Bar Chart
plt.subplot(2,2,2)

fruits = ["Apple","Banana","Orange","Mango"]
sales = [50,30,40,60]

plt.bar(fruits,sales)
plt.title("Bar Chart")
plt.xlabel("Fruits")
plt.ylabel("Sales")

# 3. Pie Chart
plt.subplot(2,2,3)

languages = ["Python","Java","C++","SQL"]
students = [40,30,20,10]

plt.pie(
    students,
    labels=languages,
    autopct="%1.1f%%",
    explode= [0.1,0,0,0],
    shadow= True
)

plt.title("Pie Chart")

# 4. Histogram
plt.subplot(2,2,4)

data = np.random.normal(50,10,1000)

plt.hist(
    data,
    bins=20,
    edgecolor="black"
)

plt.title("Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()
